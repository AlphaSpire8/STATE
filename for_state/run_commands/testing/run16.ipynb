# %% [markdown]
# ## 1.prepare the file for inference

# %%
import sys
sys.path.append('/data3/fanpeishan/state/for_state/scripts')
from prepare_test_data import prepare_test_data
prepare_test_data(
    data_in="/data1/fanpeishan/State-Tahoe-Filtered/c37.h5ad",
    data_out="/data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad",
    var_dims_path="/data3/fanpeishan/state/for_state/models/ST-Tahoe/var_dims.pkl"
)

# %% [markdown]
# ## 2.finetune

# %%
export CUDA_VISIBLE_DEVICES=1
python /data3/fanpeishan/state/for_state/scripts/finetune_v2.py \
  --model_dir /data3/fanpeishan/state/for_state/models/ST-Tahoe \
  --checkpoint /data3/fanpeishan/state/for_state/models/ST-Tahoe/final_from_preprint.ckpt \
  --adata /data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad \
  --pert_col drugname_drugconc \
  --output_lora /data3/fanpeishan/state/for_state/run_results/run16/lora_state.pth \
  --save_dir /data3/fanpeishan/state/for_state/run_results/run16/lora_out \
  --epochs 10 \
  --batch_size 1024 \
  --lr 2e-4 \
  --lora_rank 16 \
  --lora_alpha 32 \
  --use_delta_loss \
  --lambda_delta 1.0 \
  --lambda_pearson 0.5 \
  --lambda_mse 0.5 \
  --weight_decay 1e-4 \
  --target_modules transformer_backbone

  # --target_modules pert_encoder,basal_encoder,transformer_backbone

# %%
[加载] 模型: /data3/fanpeishan/state/for_state/models/ST-Tahoe/final_from_preprint.ckpt
StateTransitionPerturbationModel(
  (loss_fn): SamplesLoss()
  (pert_encoder): Sequential(
    (0): Linear(in_features=1138, out_features=1488, bias=True)
    (1): GELU(approximate='none')
    (2): Dropout(p=0.1, inplace=False)
    (3): Linear(in_features=1488, out_features=1488, bias=True)
    (4): GELU(approximate='none')
    (5): Dropout(p=0.1, inplace=False)
    (6): Linear(in_features=1488, out_features=1488, bias=True)
    (7): GELU(approximate='none')
    (8): Dropout(p=0.1, inplace=False)
    (9): Linear(in_features=1488, out_features=1488, bias=True)
  )
  (basal_encoder): Sequential(
    (0): Linear(in_features=2000, out_features=1488, bias=True)
    (1): GELU(approximate='none')
    (2): Dropout(p=0.1, inplace=False)
    (3): Linear(in_features=1488, out_features=1488, bias=True)
    (4): GELU(approximate='none')
    (5): Dropout(p=0.1, inplace=False)
    (6): Linear(in_features=1488, out_features=1488, bias=True)
    (7): GELU(approximate='none')
    (8): Dropout(p=0.1, inplace=False)
    (9): Linear(in_features=1488, out_features=1488, bias=True)
  )
  (transformer_backbone): LlamaModel(
    (embed_tokens): Embedding(32000, 1488, padding_idx=0)
    (layers): ModuleList(
      (0-5): 6 x LlamaDecoderLayer(
        (self_attn): LlamaAttention(
          (q_proj): Linear(in_features=1488, out_features=1488, bias=False)
          (k_proj): Linear(in_features=1488, out_features=1488, bias=False)
          (v_proj): Linear(in_features=1488, out_features=1488, bias=False)
          (o_proj): Linear(in_features=1488, out_features=1488, bias=False)
        )
        (mlp): LlamaMLP(
          (gate_proj): Linear(in_features=1488, out_features=5952, bias=False)
          (up_proj): Linear(in_features=1488, out_features=5952, bias=False)
          (down_proj): Linear(in_features=5952, out_features=1488, bias=False)
          (act_fn): SiLUActivation()
        )
        (input_layernorm): LlamaRMSNorm((1488,), eps=1e-06)
        (post_attention_layernorm): LlamaRMSNorm((1488,), eps=1e-06)
      )
    )
    (norm): LlamaRMSNorm((1488,), eps=1e-06)
    (rotary_emb): LlamaRotaryEmbedding()
  )
  (project_out): Sequential(
    (0): Linear(in_features=1488, out_features=1488, bias=True)
    (1): GELU(approximate='none')
    (2): Dropout(p=0.1, inplace=False)
    (3): Linear(in_features=1488, out_features=1488, bias=True)
    (4): GELU(approximate='none')
    (5): Dropout(p=0.1, inplace=False)
    (6): Linear(in_features=1488, out_features=1488, bias=True)
    (7): GELU(approximate='none')
    (8): Dropout(p=0.1, inplace=False)
    (9): Linear(in_features=1488, out_features=2000, bias=True)
  )
  (relu): ReLU()
)
[加载] 数据: /data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad
[配置] 控制组标签: '[('DMSO_TF', 0.0, 'uM')]'
[配置] Delta损失: 启用
[配置] 批次列: 未指定
[Dataset] 控制组: 45150, 扰动组: 1790797
[Dataset] 控制组均值 - 形状: torch.Size([2000]), 范数: 24.7888
[LoRA] 配置 - rank=16, alpha=32.0
[LoRA] 替换模块数量: 42
[LoRA] 可训练参数: 84
[启动] LoRA微调
[训练] 启用 Delta-Aware 损失，权重: {'lambda_delta': 1.0, 'lambda_pearson': 0.5, 'lambda_mse': 0.5}
Epoch 1/10: 100%|█████████████████████████████████████| 1749/1749 [02:45<00:00, 10.57it/s, loss=1.3010e+00, δ_mse=5.6791e-01, δ_prs=0.8984]
[Epoch 1] Loss: 1.3010e+00
  Delta MSE: 5.6791e-01, Delta Pearson: 0.8984, MSE: 5.6791e-01
Epoch 2/10: 100%|█████████████████████████████████████| 1749/1749 [02:40<00:00, 10.92it/s, loss=1.2719e+00, δ_mse=5.5753e-01, δ_prs=0.8712]
[Epoch 2] Loss: 1.2719e+00
  Delta MSE: 5.5753e-01, Delta Pearson: 0.8712, MSE: 5.5753e-01
Epoch 3/10: 100%|█████████████████████████████████████| 1749/1749 [02:46<00:00, 10.52it/s, loss=1.2664e+00, δ_mse=5.5551e-01, δ_prs=0.8663]
[Epoch 3] Loss: 1.2664e+00
  Delta MSE: 5.5551e-01, Delta Pearson: 0.8663, MSE: 5.5551e-01
Epoch 4/10: 100%|█████████████████████████████████████| 1749/1749 [02:40<00:00, 10.90it/s, loss=1.2635e+00, δ_mse=5.5440e-01, δ_prs=0.8638]
[Epoch 4] Loss: 1.2635e+00
  Delta MSE: 5.5440e-01, Delta Pearson: 0.8638, MSE: 5.5440e-01
Epoch 5/10: 100%|█████████████████████████████████████| 1749/1749 [02:39<00:00, 10.95it/s, loss=1.2616e+00, δ_mse=5.5367e-01, δ_prs=0.8622]
[Epoch 5] Loss: 1.2616e+00
  Delta MSE: 5.5367e-01, Delta Pearson: 0.8622, MSE: 5.5367e-01
Epoch 6/10: 100%|█████████████████████████████████████| 1749/1749 [02:44<00:00, 10.64it/s, loss=1.2604e+00, δ_mse=5.5322e-01, δ_prs=0.8611]
[Epoch 6] Loss: 1.2604e+00
  Delta MSE: 5.5322e-01, Delta Pearson: 0.8611, MSE: 5.5322e-01
Epoch 7/10: 100%|█████████████████████████████████████| 1749/1749 [02:44<00:00, 10.65it/s, loss=1.2595e+00, δ_mse=5.5289e-01, δ_prs=0.8604]
[Epoch 7] Loss: 1.2595e+00
  Delta MSE: 5.5289e-01, Delta Pearson: 0.8604, MSE: 5.5289e-01
Epoch 8/10: 100%|█████████████████████████████████████| 1749/1749 [02:43<00:00, 10.69it/s, loss=1.2587e+00, δ_mse=5.5254e-01, δ_prs=0.8597]
[Epoch 8] Loss: 1.2587e+00
  Delta MSE: 5.5254e-01, Delta Pearson: 0.8597, MSE: 5.5254e-01
Epoch 9/10: 100%|█████████████████████████████████████| 1749/1749 [02:42<00:00, 10.79it/s, loss=1.2580e+00, δ_mse=5.5227e-01, δ_prs=0.8591]
[Epoch 9] Loss: 1.2580e+00
  Delta MSE: 5.5227e-01, Delta Pearson: 0.8591, MSE: 5.5227e-01
Epoch 10/10: 100%|████████████████████████████████████| 1749/1749 [02:45<00:00, 10.59it/s, loss=1.2574e+00, δ_mse=5.5204e-01, δ_prs=0.8587]
[Epoch 10] Loss: 1.2574e+00
  Delta MSE: 5.5204e-01, Delta Pearson: 0.8587, MSE: 5.5204e-01
[完成] LoRA状态已保存至: /data3/fanpeishan/state/for_state/run_results/run16/lora_state.pth

# %% [markdown]
# ## 3.infer

# %%
export CUDA_VISIBLE_DEVICES=1
python /data3/fanpeishan/state/for_state/scripts/infer_lora_v2.py \
  --model_dir /data3/fanpeishan/state/for_state/models/ST-Tahoe \
  --checkpoint /data3/fanpeishan/state/for_state/models/ST-Tahoe/final_from_preprint.ckpt \
  --lora_path /data3/fanpeishan/state/for_state/run_results/run16/lora_state.pth \
  --adata /data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad \
  --pert_col drugname_drugconc \
  --output /data3/fanpeishan/state/for_state/run_results/run16/c37_infer.h5ad

# %%
INFO:__main__:[V2] Control mean mode: ENABLED                                                                                              
INFO:__main__:Loaded config from /data3/fanpeishan/state/for_state/models/ST-Tahoe/config.yaml                                             
INFO:__main__:Perturbation dim: 1138
INFO:__main__:Loading model from checkpoint: /data3/fanpeishan/state/for_state/models/ST-Tahoe/final_from_preprint.ckpt                    
StateTransitionPerturbationModel()
INFO:state.tx.models.base:DEBUG: output_space: gene
INFO:state.tx.models.base:DEBUG: gene_dim: 2000
INFO:__main__:Model cell_sentence_len=256, parameters device=cuda:0
INFO:__main__:Loading LoRA adapter from: /data3/fanpeishan/state/for_state/run_results/run16/lora_state.pth
INFO:__main__:Found LoRA file: /data3/fanpeishan/state/for_state/run_results/run16/lora_state.pth -> loading...
INFO:__main__:LoRA config: rank=16, alpha=32.0
INFO:__main__:Applying LoRA wrappers to model (rank=16, alpha=32.0)...
INFO:__main__:Created 54 LoRA modules
INFO:__main__:Successfully loaded LoRA weights for 42/42 modules
INFO:__main__:Loading AnnData from: /data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad
INFO:__main__:Using adata.X as input features: shape (1835947, 2000)
INFO:__main__:[V2] Control label: '[('DMSO_TF', 0.0, 'uM')]'
INFO:__main__:[V2] Computed control mean from 45150 control cells
INFO:__main__:[V2] Using control mean as input for ALL 1835947 samples
INFO:__main__:[V2] Input shape: (1835947, 2000), Control mean norm: 24.7888
INFO:__main__:Perturbation tensor shape: torch.Size([1835947, 1138])
INFO:__main__:Data module has 1138 perturbations in mapping
INFO:__main__:AnnData has 1137 unique perturbations
INFO:__main__:Control perturbation in data module: 'DMSO_TF'
INFO:__main__:Matched 1835947 out of 1835947 perturbations
INFO:__main__:Running inference on 1835947 samples in 7172 batches of size 256 (model's cell_sentence_len)...
Processing samples: 100%|| 1835947/1835947 [02:01<00:00, 15069.49samples/s]
INFO:__main__:Saved predictions to /data3/fanpeishan/state/for_state/run_results/run16/c37_infer.h5ad (in adata.X)
INFO:__main__:[V2] Inference completed with control mean mode: ENABLED

# %% [markdown]
# ## 4.cell-eval run

# %%
export CUDA_VISIBLE_DEVICES=1
cell-eval run \
    -ap /data3/fanpeishan/state/for_state/run_results/run16/c37_infer.h5ad \
    -ar /data3/fanpeishan/state/for_state/run_results/run14/c37_prep.h5ad \
    -o /data3/fanpeishan/state/for_state/run_results/run16/run_results \
    --control-pert "[('DMSO_TF', 0.0, 'uM')]" \
    --pert-col 'drugname_drugconc' \
    --profile full \
    --batch-size 1024 \
    --num-threads 12

# %%
import pandas as pd
results=pd.read_csv('/data3/fanpeishan/state/for_state/run_results/run16/run_results/agg_results.csv')
mean_results=results[results.statistic == 'mean'][['overlap_at_N','pearson_delta','mse']]
print(mean_results)
# Out:
#    overlap_at_N  pearson_delta       mse
# 2      0.417873       0.601307  0.018224
